# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
seattle_weather = pd.read_csv('seattle_weather.csv')

austin_weather = pd.read_csv('austin_weather.csv')

summer_2016_medals = pd.read_csv('summer2016.csv')

# crear columna 'MONTH' a partir de la columna 'DATE' (que contiene 1, 2, ..., 12)
import calendar

for df in [seattle_weather, austin_weather]:
    df['MONTH'] = df['DATE'].apply(lambda x: calendar.month_name[x])

seattle_weather.head()
# Out:
#        STATION                 NAME  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  \
# 0  USC00456295  PALMER 3 ESE, WA US     1             13.0              1.0
# 1  USC00456295  PALMER 3 ESE, WA US     2             23.0              3.0
# 2  USC00456295  PALMER 3 ESE, WA US     3             50.0             11.0
# 3  USC00456295  PALMER 3 ESE, WA US     4            108.0             40.0
# 4  USC00456295  PALMER 3 ESE, WA US     5            255.0            130.0
#
#    MLY-CLDD-BASE55  MLY-CLDD-BASE57  MLY-CLDD-BASE60  MLY-CLDD-BASE70  \
# 0          -7777.0              0.0              0.0              0.0
# 1          -7777.0          -7777.0              0.0              0.0
# 2              1.0          -7777.0          -7777.0              0.0
# 3             12.0              7.0              3.0          -7777.0
# 4             56.0             38.0             19.0              1.0
#
#    MLY-CLDD-BASE72  ...  MLY-TMIN-AVGNDS-LSTH070  MLY-TMIN-NORMAL  \
# ...

# %% [markdown]
# Cambio de estilo
#
# Seleccionar un estilo para utilizarlo afecta a todas las visualizaciones que se creen después de seleccionar este estilo.
#
# Aquí practicarás el trazado de gráficos de datos en dos estilos diferentes. Los datos que vas a utilizar son los mismos datos meteorológicos que utilizamos en la primera lección: tendrás a tu disposición el DataFrame seattle_weather y el DataFrame austin_weather, ambos con registros de la temperatura media de cada mes.
#
# Selecciona el estilo 'ggplot', crea una nueva Figura llamada fig, y un nuevo objeto Ejes llamado ax con plt.subplots.
#
# Selecciona el estilo 'Solarize_Light2', crea una nueva Figura llamada fig, y un nuevo objeto Ejes llamado ax con plt.subplots.

# %%
# Use the "ggplot" style and create new Figure/Axes
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %%
# Use the "Solarize_Light2" style and create new Figure/Axes
plt.style.use('Solarize_Light2')
fig, ax = plt.subplots()
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
plt.show()
fig.savefig('my_figure.png')
fig.savefig("my_figure_300dpi.png", dpi=300)

# %%
# Use the "Solarize_Light2" style and create new Figure/Axes
plt.style.use('Solarize_Light2')
fig, ax = plt.subplots()
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
plt.show()
fig.set_size_inches([5, 3])
fig.savefig('figure_5_3.png')

# %% [markdown]
# Valores únicos de una columna
#
# Uno de los principales puntos fuertes de Matplotlib es que puede automatizarse para adaptarse a los datos que recibe como entrada. Por ejemplo, si recibes datos que tienen un número desconocido de categorías, puedes crear un diagrama de barras que tenga barras para cada categoría.
#
# En este ejercicio y en el siguiente, volverás a visualizar el peso de los atletas en los Juegos Olímpicos de verano de 2016, a partir de un conjunto de datos que contiene un número desconocido de ramas deportivas. Esto se cargará en memoria como un objeto pandas DataFrame llamado summer_2016_medals, que tiene una columna llamada "Sport" que te indica a qué rama del deporte corresponde cada fila. También hay una columna "Weight" que te indica el peso de cada atleta.
#
# En este ejercicio, extraeremos los valores únicos de la columna "Sport"
#
# Crea una variable llamada sports_column que contenga los datos de la columna "Sport" del objeto DataFrame.
# Utiliza el método unique de esta variable para encontrar todos los deportes únicos diferentes que están presentes en estos datos, y asigna estos valores a una nueva variable llamada sports.
# Imprime la variable sports en la consola.

# %%
sports_column = summer_2016_medals['Sport']

sports = sports_column.unique()

print(sports)
# Out:
# <StringArray>
# [               'Rowing',             'Taekwondo',              'Handball',
#              'Wrestling',            'Gymnastics',              'Swimming',
#             'Basketball',                'Boxing',            'Volleyball',
#              'Athletics',          'Rugby Sevens',                  'Judo',
#    'Rhythmic Gymnastics',         'Weightlifting',         'Equestrianism',
#              'Badminton',            'Water Polo',              'Football',
#                'Fencing',              'Shooting',               'Sailing',
#       'Beach Volleyball',              'Canoeing',                'Hockey',
#                'Cycling',                'Tennis',                'Diving',
#           'Table Tennis',             'Triathlon',               'Archery',
#  'Synchronized Swimming',     'Modern Pentathlon',          'Trampolining',
#                   'Golf']
# Length: 34, dtype: str

# %% [markdown]
# Automatizar visualización
#
# Uno de los principales puntos fuertes de Matplotlib es que puede automatizarse para adaptarse a los datos que recibe como entrada. Por ejemplo, si recibes datos que tienen un número desconocido de categorías, puedes crear un diagrama de barras que tenga barras para cada categoría.
#
# Esto es lo que harás en este ejercicio. Volverás a visualizar datos sobre los ganadores de medallas en los Juegos Olímpicos de verano de 2016, pero esta vez tendrás un conjunto de datos que contiene un número desconocido de ramas deportivas. Esto se cargará en memoria como un objeto pandas DataFrame llamado summer_2016_medals, que tiene una columna llamada "Sport" que te indica a qué rama del deporte corresponde cada fila. También hay una columna "Weight" que te indica el peso de cada atleta.
#
# -Itera sobre los valores de sports y establece sport como tu variable de bucle.
# -En cada iteración, extrae las filas en las que la columna "Sport" sea igual a sport.
# Añade una barra al objeto ax proporcionado, etiquetada con el nombre del deporte, con la media de la columna "Weight" como altura, y la desviación típica como barra de error en el eje y.
# -Guarda la figura en el archivo "sports_weights.png".

# %%
fig, ax = plt.subplots()

for sport in sports:
    sport_df = summer_2016_medals[summer_2016_medals['Sport'] == sport]
    ax.bar(sport, sport_df['Weight'].mean(), yerr=sport_df['Weight'].std())
ax.set_ylabel("Weight")
ax.set_xticklabels(sports, rotation=90)

fig.savefig('sports_weights.png')
# Out:
# /tmp/ipykernel_3998/3307272885.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator. Otherwise, ticks may be mislabeled.
#   ax.set_xticklabels(sports, rotation=90)
